# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
energy, angle_x, angle_y, z, x, y = np.loadtxt('beam1.dat', unpack=True)

# %%
plt.plot(z, energy)
plt.xlabel('z position')
plt.ylabel('Energy')

# %%
plt.plot(x,z)
